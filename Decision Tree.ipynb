# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("https://raw.githubusercontent.com/shrikant-temburwar/Wine-Quality-Dataset/master/winequality-red.csv", sep= ';')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %%
df.duplicated().sum()
# Out:
# 240

# %%
df= df.drop_duplicates()

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
X= df.iloc[:,:-1]

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y= df.quality

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 5       5
#        ..
# 1593    6
# 1594    5
# 1595    6
# 1597    5
# 1598    6
# Name: quality, Length: 1359, dtype: int64

# %%
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.33,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model= DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_train,y_train)
# Out:
# 1.0

# %%
y_pred= model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.47216035634743875

# %%
grid_param = {
    'criterion': ['gini', 'entropy'],
    'max_depth' : range(2,32,1),
    'min_samples_leaf' : range(1,10,1),
    'min_samples_split': range(2,10,1),
    'splitter' : ['best', 'random']
    
}

# %%
from sklearn.model_selection import GridSearchCV
grid_search=GridSearchCV(estimator=model,param_grid=grid_param,cv=5)

# %%
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 32),
#                          'min_samples_leaf': range(1, 10),
#                          'min_samples_split': range(2, 10),
#                          'splitter': ['best', 'random']})

# %%
grid_search.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 8,
#  'min_samples_leaf': 6,
#  'min_samples_split': 3,
#  'splitter': 'random'}

# %%
model_with_best_params=DecisionTreeClassifier(criterion= 'gini',max_depth= 4,min_samples_leaf= 1,min_samples_split= 8,splitter='random')

# %%
model_with_best_params.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, min_samples_split=8, splitter='random')

# %%
y_prediction2=model_with_best_params.predict(X_test)

# %%
accuracy_score(y_test,y_prediction2)
# Out:
# 0.5701559020044543

# %%
from sklearn import tree
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(25,15))
tree.plot_tree(model_with_best_params,filled=True,fontsize=10)
# Out:
# [Text(0.49107142857142855, 0.9, 'X[10] <= 10.87\ngini = 0.652\nsamples = 910\nvalue = [5, 38, 385, 354, 115, 13]'),
#  Text(0.26785714285714285, 0.7, 'X[1] <= 0.819\ngini = 0.582\nsamples = 625\nvalue = [4, 26, 339, 215, 39, 2]'),
#  Text(0.14285714285714285, 0.5, 'X[1] <= 0.332\ngini = 0.58\nsamples = 584\nvalue = [4, 19, 315, 205, 39, 2]'),
#  Text(0.07142857142857142, 0.3, 'X[8] <= 3.275\ngini = 0.674\nsamples = 66\nvalue = [0, 0, 20, 27, 17, 2]'),
#  Text(0.03571428571428571, 0.1, 'gini = 0.649\nsamples = 31\nvalue = [0, 0, 4, 14, 11, 2]'),
#  Text(0.10714285714285714, 0.1, 'gini = 0.624\nsamples = 35\nvalue = [0, 0, 16, 13, 6, 0]'),
#  Text(0.21428571428571427, 0.3, 'X[10] <= 9.613\ngini = 0.554\nsamples = 518\nvalue = [4, 19, 295, 178, 22, 0]'),
#  Text(0.17857142857142858, 0.1, 'gini = 0.452\nsamples = 265\nvalue = [2, 11, 184, 67, 1, 0]'),
#  Text(0.25, 0.1, 'gini = 0.607\nsamples = 253\nvalue = [2, 8, 111, 111, 21, 0]'),
# ...
